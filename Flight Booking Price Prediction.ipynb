# %%
# importing the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the Dataset
df = pd.read_csv(r"C:\Users\hp\Downloads\Flight_Booking\Flight_Booking.csv")
df
# Out:
#         Unnamed: 0   airline   flight source_city departure_time stops  \
# 0                0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1                1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2                2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3                3   Vistara   UK-995       Delhi        Morning  zero
# 4                4   Vistara   UK-963       Delhi        Morning  zero
# ...            ...       ...      ...         ...            ...   ...
# 300148      300148   Vistara   UK-822     Chennai        Morning   one
# 300149      300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150      300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151      300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152      300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price
# ...

# %%
# Replacing the column name
df.rename(columns = {'Unnamed: 0': 'Index'}, inplace = True)
df
# Out:
#          Index   airline   flight source_city departure_time stops  \
# 0            0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1            1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2            2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3            3   Vistara   UK-995       Delhi        Morning  zero
# 4            4   Vistara   UK-963       Delhi        Morning  zero
# ...        ...       ...      ...         ...            ...   ...
# 300148  300148   Vistara   UK-822     Chennai        Morning   one
# 300149  300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150  300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151  300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152  300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price
# 0               Night           Mumbai   Economy      2.17          1   5953
# ...

# %%
# Droping the un-relevant column
df = df.drop(['Index'], axis = 1)

# %% [markdown]
# #### EDA

# %%
df.shape
# Out:
# (300153, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           300153 non-null  object
#  1   flight            300153 non-null  object
#  2   source_city       300153 non-null  object
#  3   departure_time    300153 non-null  object
#  4   stops             300153 non-null  object
#  5   arrival_time      300153 non-null  object
#  6   destination_city  300153 non-null  object
#  7   class             300153 non-null  object
#  8   duration          300153 non-null  float64
#  9   days_left         300153 non-null  int64
#  10  price             300153 non-null  int64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 25.2+ MB

# %%
df.describe()
# Out:
#             duration      days_left          price
# count  300153.000000  300153.000000  300153.000000
# mean       12.221021      26.004751   20889.660523
# std         7.191997      13.561004   22697.767366
# min         0.830000       1.000000    1105.000000
# 25%         6.830000      15.000000    4783.000000
# 50%        11.250000      26.000000    7425.000000
# 75%        16.170000      38.000000   42521.000000
# max        49.830000      49.000000  123071.000000

# %%
df.isnull().sum()
# Out:
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##### Now, we will go for outliers detection and removal

# %% [markdown]
# ##### First we will check for normal distribution of data

# %%
for col in df.columns:
    if df[col].dtypes in ['int64', 'float64']:
        plt.figure(figsize=(16,5))
        sns.distplot(df[col])
        plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ##### Our Features is not Normally Distributed, so we will go with IQR method for removal of outliers

# %%
for col in df.columns:
    if df[col].dtypes == 'int64' or df[col].dtypes == 'float64':
        plt.boxplot(df[col])
        plt.show()

# %%
for col in df.columns:
    if df[col].dtypes == 'int64' or df[col].dtypes == 'float64':
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3- Q1
        upper_fence = Q3 + 1.5*IQR
        lower_fence = Q1 - 1.5*IQR
        df = df[(df[col]>= lower_fence) & (df[col]<=upper_fence)]

# %%
for col in df.columns:
    if df[col].dtypes in ['int64', 'float64']:
        plt.figure(figsize=(16,5))
        sns.distplot(df[col])
        plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
for col in df.columns:
    if df[col].dtypes == 'int64' or df[col].dtypes == 'float64':
        plt.boxplot(df[col])
        plt.show()

# %%
df.shape
# Out:
# (297921, 11)

# %%
# By removing outliers we can see we lost some of the data
300153 - 297921
# Out:
# 2232

# %% [markdown]
# ##### Outliers has been removed from the dataset

# %% [markdown]
# ### Data Visualization

# %%
plt.figure(figsize = (20,5))
sns.lineplot(x=df['airline'], y=df['price'])
plt.xlabel('Airline')
plt.ylabel('Ticket Price')
plt.title('Airline Vs Ticket Price', fontsize = 30)
plt.show()

# %%
plt.figure(figsize = (20,10))
sns.lineplot(data = df, x='days_left', y = 'price')
plt.title('Days Left to Departure Vs Ticket Price', fontsize=30)
plt.show()

# %%
plt.figure(figsize = (20, 20))
sns.barplot(data = df,x = 'airline', y= 'price')
plt.title('Airline Vs Ticket Price', fontsize=30)
plt.show()

# %%
plt.figure(figsize = (20, 20))
sns.histplot(data = df,x = 'airline', y= 'price', bins=30, binwidth=5, kde= True, cbar='green')
plt.title('Airline Vs Ticket Price', fontsize=30)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.barplot(x = df['class'], y= df['price'])
plt.title('Class Vs Ticket Price', fontsize=30)
plt.show()

# %%
fig,ax = plt.subplots(1,2, figsize=(20,10))
sns.lineplot(x = df['days_left'], y = df['price'],hue = df['source_city'], ax = ax[0])
sns.lineplot(x=df['days_left'], y = df['price'], hue= df['destination_city'], ax=ax[1])
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 297921 entries, 0 to 300152
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           297921 non-null  object
#  1   flight            297921 non-null  object
#  2   source_city       297921 non-null  object
#  3   departure_time    297921 non-null  object
#  4   stops             297921 non-null  object
#  5   arrival_time      297921 non-null  object
#  6   destination_city  297921 non-null  object
#  7   class             297921 non-null  object
#  8   duration          297921 non-null  float64
#  9   days_left         297921 non-null  int64
#  10  price             297921 non-null  int64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 35.3+ MB

# %%
plt.figure(figsize = (15, 23))

plt.subplot(4,2,1)
sns.countplot(x=df['airline'])
plt.title('Frequency of Airline')

plt.subplot(4,2,2)
sns.countplot(x=df['source_city'])
plt.title('Frequency of Source City')

plt.subplot(4,2,3)
sns.countplot(x=df['departure_time'])
plt.title('Frequency of Departure Time')

plt.subplot(4,2,4)
sns.countplot(x=df['stops'])
plt.title('Frequency of Stops')

plt.subplot(4,2,5)
sns.countplot(x=df['arrival_time'])
plt.title('Frequency of Arrival Time')

plt.subplot(4,2,6)
sns.countplot(x=df['destination_city'])
plt.title('Frequency of Destination City')

plt.subplot(4,2,7)
sns.countplot(x=df['class'])
plt.title('Frequency of Class')

plt.subplot(4,2,8)
sns.countplot(x=df['duration'])
plt.title('Frequency of Duration')

# plt.subplot(4,2,9)
# sns.countplot(x=df['days_left'])
# plt.title('Frequency of Days Left')

# plt.subplot(4,2,10)
# sns.countplot(x=df['price'])
# plt.title('Frequency of Price')
# Out:
# Text(0.5, 1.0, 'Frequency of Duration')

# %% [markdown]
# #### Encoding my categorical column into numerical column

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for col in df.columns:
    if df[col].dtypes == object:
        df[col] = le.fit_transform(df[col])
        
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 297921 entries, 0 to 300152
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           297921 non-null  int32
#  1   flight            297921 non-null  int32
#  2   source_city       297921 non-null  int32
#  3   departure_time    297921 non-null  int32
#  4   stops             297921 non-null  int32
#  5   arrival_time      297921 non-null  int32
#  6   destination_city  297921 non-null  int32
#  7   class             297921 non-null  int32
#  8   duration          297921 non-null  float64
#  9   days_left         297921 non-null  int64
#  10  price             297921 non-null  int64
# dtypes: float64(1), int32(8), int64(2)
# memory usage: 18.2 MB

# %% [markdown]
# #### Feature Selection

# %%
sns.heatmap(df.corr(), annot = True, cmap='coolwarm', linewidth=2, fmt = '.1g')
plt.show()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list = []

for col in df.columns:
    if ((df[col].dtypes != 'object') & (col!='price')):
        col_list.append(col)
        
x=df[col_list]
vif_data = pd.DataFrame()
vif_data['feature'] = x.columns
vif_data['VIF']=[variance_inflation_factor(x.values, i) for i in range(len(x.columns))]

print(vif_data)
# Out:
#             feature        VIF
# 0           airline   6.685307
# 1            flight  12.662201
# 2       source_city   2.985762
# 3    departure_time   2.827016
# 4             stops   1.465479
# 5      arrival_time   3.788111
# 6  destination_city   2.924579
# 7             class   2.839927
# 8          duration   5.002091
# 9         days_left   4.088904

# %%
df = df.drop(columns=['flight'])

# %%
col_list = []

for col in df.columns:
    if ((df[col].dtypes != 'object') & (col!='price')):
        col_list.append(col)
        
x=df[col_list]
vif_data = pd.DataFrame()
vif_data['feature'] = x.columns
vif_data['VIF']=[variance_inflation_factor(x.values, i) for i in range(len(x.columns))]

print(vif_data)
# Out:
#             feature       VIF
# 0           airline  3.409482
# 1       source_city  2.946912
# 2    departure_time  2.803413
# 3             stops  1.452338
# 4      arrival_time  3.690532
# 5  destination_city  2.892788
# 6             class  2.837463
# 7          duration  4.316253
# 8         days_left  3.998231

# %% [markdown]
# ##### So, I've set Threshold value for vif  is 5, whatever comes aboves that we will remove it

# %% [markdown]
# #### Splitting my Dataset into Independent variable and Dependent Variable

# %%
x = df.iloc[:,:-1]
x
# Out:
#         airline  source_city  departure_time  stops  arrival_time  \
# 0             4            2               2      2             5
# 1             4            2               1      2             4
# 2             0            2               1      2             1
# 3             5            2               4      2             0
# 4             5            2               4      2             4
# ...         ...          ...             ...    ...           ...
# 300148        5            1               4      0             2
# 300149        5            1               0      0             5
# 300150        5            1               1      0             5
# 300151        5            1               1      0             2
# 300152        5            1               4      0             2
#
#         destination_city  class  duration  days_left
# 0                      5      1      2.17          1
# 1                      5      1      2.33          1
# ...

# %%
y = df['price']
y
# Out:
# 0          5953
# 1          5953
# 2          5956
# 3          5955
# 4          5955
#           ...
# 300148    69265
# 300149    77105
# 300150    79099
# 300151    81585
# 300152    81585
# Name: price, Length: 297921, dtype: int64

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state=10)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

x_scaled = sc.fit_transform(x)
x_scaled=pd.DataFrame(x_scaled)

print(x_scaled)
# Out:
#                0         1         2         3         4         5         6  \
# 0       0.486949 -0.331999 -0.240492  2.573771  1.105104  1.382695  0.674351
# 1       0.486949 -0.331999 -0.810676  2.573771  0.531022  1.382695  0.674351
# 2      -1.696700 -0.331999 -0.810676  2.573771 -1.191224  1.382695  0.674351
# 3       1.032862 -0.331999  0.899877  2.573771 -1.765306  1.382695  0.674351
# 4       1.032862 -0.331999  0.899877  2.573771  0.531022  1.382695  0.674351
# ...          ...       ...       ...       ...       ...       ...       ...
# 297916  1.032862 -0.903020  0.899877 -0.425003 -0.617142  0.236093 -1.482907
# 297917  1.032862 -0.903020 -1.380861 -0.425003  1.105104  0.236093 -1.482907
# 297918  1.032862 -0.903020 -0.810676 -0.425003  1.105104  0.236093 -1.482907
# 297919  1.032862 -0.903020 -0.810676 -0.425003 -0.617142  0.236093 -1.482907
# 297920  1.032862 -0.903020  0.899877 -0.425003 -0.617142  0.236093 -1.482907
#
#                7         8
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size = 0.2, random_state= 20)

# %% [markdown]
# ## Creating the Models

# %% [markdown]
# #### Linear Regression

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
y_pred = lr.predict(x_test)

# %%
difference = pd.DataFrame(np.c_[y_test, y_pred], columns = ['Actual_Value', 'Predicted_Value'])
difference
# Out:
#        Actual_Value  Predicted_Value
# 0            6680.0      7661.589695
# 1            6174.0      5828.954562
# 2            2329.0       248.526833
# 3           22175.0     10988.355534
# 4           55983.0     47878.918996
# ...             ...              ...
# 59580        2723.0      2073.902670
# 59581        4637.0      4047.427594
# 59582        3467.0      1793.169093
# 59583        4363.0      4912.190084
# 59584        1755.0      6422.887987
#
# [59585 rows x 2 columns]

# %%
from sklearn.metrics import *  # it will import all the metrics library form the package

print(r2_score(y_test, y_pred))

print(mean_absolute_error(y_test, y_pred))

print(mean_absolute_percentage_error(y_test, y_pred))

print(mean_squared_error(y_test, y_pred))

print(np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# 0.9052756616061899
# 4646.4380727883645
# 0.4413334878697566
# 48401801.89535191
# 6957.140353288261

# %%
sns.distplot(y_test, label='Actual')
sns.distplot(y_pred, label='Predicted')
plt.legend()
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #### Decison Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

dt  = DecisionTreeRegressor()

dt.fit(x_train, y_train)

y_pred = dt.predict(x_test)

print('R2 Score: ', r2_score(y_test, y_pred))

print('Mean Absolute Error: ', mean_absolute_error(y_test, y_pred))

print('Mean Absolute Percentage Error: ', mean_absolute_percentage_error(y_test, y_pred))

print('Mean Sq Error: ', mean_squared_error(y_test, y_pred))

print('Root Mean Sq Error: ', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score:  0.9761826520308059
# Mean Absolute Error:  1159.5606416603732
# Mean Absolute Percentage Error:  0.0747391220591941
# Mean Sq Error:  12170077.697295647
# Root Mean Sq Error:  3488.5638445204995

# %% [markdown]
# #### Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor()

rf.fit(x_train, y_train)

y_pred = rf.predict(x_test)

print('R2 Score: ', r2_score(y_test, y_pred))

print('Mean Absolute Error: ', mean_absolute_error(y_test, y_pred))

print('Mean Absolute Percentage Error: ', mean_absolute_percentage_error(y_test, y_pred))

print('Mean Sq Error: ', mean_squared_error(y_test, y_pred))

print('Root Mean Sq Error: ', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R2 Score:  0.9853926423714647
# Mean Absolute Error:  1071.5955628517884
# Mean Absolute Percentage Error:  0.0710944328938089
# Mean Sq Error:  7463999.666184222
# Root Mean Sq Error:  2732.0321495517255

# %%
sns.distplot(y_test, label='Actual')
sns.distplot(y_pred, label='Predicted')
plt.legend()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
